# %%
import riversound, glob, obspy, matplotlib, datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
## run this code if you're using ipython and it doesn't show plot windows
# %matplotlib qt 
## FFT works best when data length is a power of 2, so use this function to help determine window size.
def next_power_2(x):
    return int(2**np.ceil(np.log2(x)))

def interp_times(t_out, t, q):
    t_out = np.array([x.timestamp() for x in t_out])
    t = np.array([x.timestamp() for x in t])
    return np.interp(t_out, t, q)

def reformat(l): # turn list l into a numpy array
    lengths = np.array([len(i) for i in l])
    normal_length = lengths[lengths > 0][0]
    if any((lengths != 0) & (lengths != normal_length)):
        raise ValueError('nonzero lengths of elements of l must all be the same')
    for i in np.where(lengths == 0)[0]:
        l[i] = np.zeros(normal_length)
    return np.array(l)
    
## set year, frequency bands, and site, add path_audible and path_infrasound
year = '22'
site = 'CON1E'
season = 'Spring'
infra_freqs_low = [5,20]
infra_freqs_high = [20,40]
infra_power_band_limit = [[] for i in range(len(infra_freqs_low))]
aud_freqs_low = [50]
aud_freqs_high = [500]
aud_power_band_limit = [[] for i in range(len(aud_freqs_low))]

path = '/home/scott/bender/gradschool/data/' + site + '_all/'
station_name = ' ' + site + ' 20' + year
path_infrasound = path + 'infra'
path_audible = path + 'aud' 
day1 = obspy.UTCDateTime('20' + year + '-01-01')
day2 = obspy.UTCDateTime('20' + year + '-08-12')
n_days = int(np.round((day2 - day1)/86400)) # length of study period in days

# if site == 'CON1*' or 'FB*':
#     aud_files  = sorted(glob.glob(path_audible + '*.WAV'))
## Enter the times of day (UTC) to read data from.
start_hour = 3 + 6 # 6 is time zone difference vs UTC
end_hour = 4 + 6
plot_times = np.zeros(n_days, dtype = object)

# For 2-D data like these, it's a little easier to initialize as an empty list and then convert to
# np.array. Reason is because audiomoth data can have multiple sample rates, and because of that
## we don't know the number of points in the spectrum until after we start reading files.
times_infrasound = []
meanspec_list_infrasound = [] 
medspec_list_infrasound = []
power_infrasound = []
times_audible = []
meanspec_list_audible = []
medspec_list_audible = []
power_audible = []

# %%
## Loop through all the days, read the data, calculate spectra, and save to outputs
for i in range(n_days):
    current_day = day1 + i*86400
    t1 = current_day.replace(hour = start_hour)
    t2 = current_day.replace(hour = end_hour)
    
    tr_infrasound, tr_audible = riversound.read_infrasound_audible(t1, t2, path_infrasound, path_audible) #infrasound_sensor_response_file = '/home/scott/anaconda3/envs/gem/lib/python3.9/site-packages/gemlog/data/response/sensor/RESP.XX.IS000..BDF.GEMV0.26.0_0023', infrasound_logger_response_file = '/home/scott/anaconda3/envs/gem/lib/python3.9/site-packages/gemlog/data/response/datalogger/RESP.XX.GM002..HHZ.GEMINFRAV1.0.100'
    nfft_infrasound = next_power_2(10 / tr_infrasound.stats.delta) # >10-sec windows for freq resolution finer than 0.1 Hz
    print([i, current_day, tr_infrasound, tr_audible])
        
    nfft_audible = next_power_2(0.1 / tr_audible.stats.delta) # >0.1-sec windows for freq res finer than 10 Hz
    plot_times[i] = current_day.datetime
        #    times_infrasound.append((tr_infrasound.stats.starttime + 0.5*(tr_infrasound.stats.endtime - tr_infrasound.stats.starttime)).datetime)
    times_infrasound.append(t1.datetime)
    times_audible.append(t1.datetime)

    ## infrasound
    # try: # check whether the data can be processed (i.e., make sure it isn't missing)
    #     tr_infrasound.filter('highpass', freq = 1, zerophase = True)
    #     spec_info = riversound.spectrum(tr_infrasound, nfft = nfft_infrasound, kurtosis_threshold = 0.5)
    # except: # do nothing if there's an error in the above code block
    #     medspec_list_infrasound.append([])
    #     meanspec_list_infrasound.append([])
    #     power_infrasound.append(np.nan)
    # else: # append the results to the output lists if there's no error
    #     freqs_infrasound_all = spec_info['freqs']
    #     medspec_list_infrasound.append(spec_info['median'])
    #     meanspec_list_infrasound.append(spec_info['mean'])
    #     specgram_all = spec_info['specgram']
    #     power_infrasound.append(np.sum(spec_info['median']) * np.diff(spec_info['freqs'])[0]) # integral spec * df
    #     for k in [0,1]: # change to 0,1,2... for more n bands defined in freqs low and high
    #             indices_infra = (freqs_infrasound_all > infra_freqs_low[k]) & (freqs_infrasound_all < infra_freqs_high[k])
    #             infra_power_band_limit[k].append(np.sum(spec_info['median'][indices_infra]) * np.diff(spec_info['freqs'])[0])
    # ## audible
    try:
        spec_info = riversound.spectrum(tr_audible, nfft = nfft_audible, kurtosis_threshold= 0.5)
        assert len(spec_info['mean']) > 0 # raises an exception if an empty result is returned
    except:
        medspec_list_audible.append([])
        meanspec_list_audible.append([])
        power_audible.append(np.nan)
    else:
        freqs_audible_all = spec_info['freqs']
        medspec_list_audible.append(spec_info['median'])
        meanspec_list_audible.append(spec_info['mean'])
        specgram_all = spec_info['specgram']
        power_audible.append(np.sum(spec_info['median']) * np.diff(spec_info['freqs'])[0])
        for k in [0]: # audible
                indices_aud = (freqs_audible_all > aud_freqs_low[k]) & (freqs_audible_all < aud_freqs_high[k])
                aud_power_band_limit[k].append(np.sum(spec_info['median'][indices_aud]) * np.diff(spec_info['freqs'])[0])
# Out:
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220101_090000.WAV
# No infrasound files found for these times
# [0, UTCDateTime(2022, 1, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37678b0>, <obspy.core.trace.Trace object at 0x7f1ec3767b20>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220102_090000.WAV
# No infrasound files found for these times
# [1, UTCDateTime(2022, 1, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37a7c70>, <obspy.core.trace.Trace object at 0x7f1ec37a7e80>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220103_090000.WAV
# No infrasound files found for these times
# [2, UTCDateTime(2022, 1, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37e7d60>, <obspy.core.trace.Trace object at 0x7f1ec37e7f70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220104_090000.WAV
# No infrasound files found for these times
# [3, UTCDateTime(2022, 1, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec381dbb0>, <obspy.core.trace.Trace object at 0x7f1ec381dd30>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220105_090000.WAV
# No infrasound files found for these times
# [4, UTCDateTime(2022, 1, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38dfd30>, <obspy.core.trace.Trace object at 0x7f1ec38dff40>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220106_090000.WAV
# No infrasound files found for these times
# [5, UTCDateTime(2022, 1, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec399fe20>, <obspy.core.trace.Trace object at 0x7f1ec399ffa0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220107_090000.WAV
# No infrasound files found for these times
# [6, UTCDateTime(2022, 1, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec392bee0>, <obspy.core.trace.Trace object at 0x7f1ec392c0a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220108_090000.WAV
# No infrasound files found for these times
# [7, UTCDateTime(2022, 1, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3876ee0>, <obspy.core.trace.Trace object at 0x7f1ec38641f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220109_090000.WAV
# No infrasound files found for these times
# [8, UTCDateTime(2022, 1, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38dff70>, <obspy.core.trace.Trace object at 0x7f1ec38e01c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220110_090000.WAV
# No infrasound files found for these times
# [9, UTCDateTime(2022, 1, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a1130>, <obspy.core.trace.Trace object at 0x7f1ec39a0fa0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220111_090000.WAV
# No infrasound files found for these times
# [10, UTCDateTime(2022, 1, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec379c130>, <obspy.core.trace.Trace object at 0x7f1ec379c310>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220112_090000.WAV
# No infrasound files found for these times
# [11, UTCDateTime(2022, 1, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37cf160>, <obspy.core.trace.Trace object at 0x7f1ec37cf370>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220113_090000.WAV
# No infrasound files found for these times
# [12, UTCDateTime(2022, 1, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3931070>, <obspy.core.trace.Trace object at 0x7f1ec39312e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220114_090000.WAV
# No infrasound files found for these times
# [13, UTCDateTime(2022, 1, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a3250>, <obspy.core.trace.Trace object at 0x7f1ec39a33d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220115_090000.WAV
# No infrasound files found for these times
# [14, UTCDateTime(2022, 1, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37bf310>, <obspy.core.trace.Trace object at 0x7f1ec37bf520>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220116_090000.WAV
# No infrasound files found for these times
# [15, UTCDateTime(2022, 1, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38f03a0>, <obspy.core.trace.Trace object at 0x7f1ec38f06a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220117_090000.WAV
# No infrasound files found for these times
# [16, UTCDateTime(2022, 1, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37fa430>, <obspy.core.trace.Trace object at 0x7f1ec37fa640>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220118_090000.WAV
# No infrasound files found for these times
# [17, UTCDateTime(2022, 1, 18, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a24c0>, <obspy.core.trace.Trace object at 0x7f1ec39a26d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220119_090000.WAV
# No infrasound files found for these times
# [18, UTCDateTime(2022, 1, 19, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37b65b0>, <obspy.core.trace.Trace object at 0x7f1ec37b6790>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220120_090000.WAV
# No infrasound files found for these times
# [19, UTCDateTime(2022, 1, 20, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38e0640>, <obspy.core.trace.Trace object at 0x7f1ec38e0820>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220121_090000.WAV
# No infrasound files found for these times
# [20, UTCDateTime(2022, 1, 21, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37d56d0>, <obspy.core.trace.Trace object at 0x7f1ec37d58b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220122_090000.WAV
# No infrasound files found for these times
# [21, UTCDateTime(2022, 1, 22, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39ae610>, <obspy.core.trace.Trace object at 0x7f1ec39ae790>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220123_090000.WAV
# No infrasound files found for these times
# [22, UTCDateTime(2022, 1, 23, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec382f790>, <obspy.core.trace.Trace object at 0x7f1ec382f9a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220124_090000.WAV
# No infrasound files found for these times
# [23, UTCDateTime(2022, 1, 24, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393d940>, <obspy.core.trace.Trace object at 0x7f1ec393d190>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220125_090000.WAV
# No infrasound files found for these times
# [24, UTCDateTime(2022, 1, 25, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38f48b0>, <obspy.core.trace.Trace object at 0x7f1ec38f4ac0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220126_090000.WAV
# No infrasound files found for these times
# [25, UTCDateTime(2022, 1, 26, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3800af0>, <obspy.core.trace.Trace object at 0x7f1ec3800c10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220127_090000.WAV
# No infrasound files found for these times
# [26, UTCDateTime(2022, 1, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38399d0>, <obspy.core.trace.Trace object at 0x7f1ec3839be0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220128_090000.WAV
# No infrasound files found for these times
# [27, UTCDateTime(2022, 1, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3937ac0>, <obspy.core.trace.Trace object at 0x7f1ec3937ca0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220129_090000.WAV
# No infrasound files found for these times
# [28, UTCDateTime(2022, 1, 29, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38d5b50>, <obspy.core.trace.Trace object at 0x7f1ec38d5d30>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220130_090000.WAV
# No infrasound files found for these times
# [29, UTCDateTime(2022, 1, 30, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37dcb80>, <obspy.core.trace.Trace object at 0x7f1ec37dcd90>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220131_090000.WAV
# No infrasound files found for these times
# [30, UTCDateTime(2022, 1, 31, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3814a90>, <obspy.core.trace.Trace object at 0x7f1ec3814d00>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220201_090000.WAV
# No infrasound files found for these times
# [31, UTCDateTime(2022, 2, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393cbb0>, <obspy.core.trace.Trace object at 0x7f1ec393ceb0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220202_090000.WAV
# No infrasound files found for these times
# [32, UTCDateTime(2022, 2, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38f3d30>, <obspy.core.trace.Trace object at 0x7f1ec38f3f10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220203_090000.WAV
# No infrasound files found for these times
# [33, UTCDateTime(2022, 2, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37e9d60>, <obspy.core.trace.Trace object at 0x7f1ec37e9f70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220204_090000.WAV
# No infrasound files found for these times
# [34, UTCDateTime(2022, 2, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39b2df0>, <obspy.core.trace.Trace object at 0x7f1ec39b2fd0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220205_090000.WAV
# No infrasound files found for these times
# [35, UTCDateTime(2022, 2, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3927e80>, <obspy.core.trace.Trace object at 0x7f1ec390e0d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220206_090000.WAV
# No infrasound files found for these times
# [36, UTCDateTime(2022, 2, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38fef10>, <obspy.core.trace.Trace object at 0x7f1ec38f5160>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220207_090000.WAV
# No infrasound files found for these times
# [37, UTCDateTime(2022, 2, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37f2040>, <obspy.core.trace.Trace object at 0x7f1ec37f21f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220208_090000.WAV
# No infrasound files found for these times
# [38, UTCDateTime(2022, 2, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38300d0>, <obspy.core.trace.Trace object at 0x7f1ec3830280>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220209_090000.WAV
# No infrasound files found for these times
# [39, UTCDateTime(2022, 2, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39410d0>, <obspy.core.trace.Trace object at 0x7f1ec39411f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220210_090000.WAV
# No infrasound files found for these times
# [40, UTCDateTime(2022, 2, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3994190>, <obspy.core.trace.Trace object at 0x7f1ec39944c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220211_090000.WAV
# No infrasound files found for these times
# [41, UTCDateTime(2022, 2, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38cc2e0>, <obspy.core.trace.Trace object at 0x7f1ec38cc4c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220212_090000.WAV
# No infrasound files found for these times
# [42, UTCDateTime(2022, 2, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3825310>, <obspy.core.trace.Trace object at 0x7f1ec3825520>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220213_090000.WAV
# No infrasound files found for these times
# [43, UTCDateTime(2022, 2, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37e83a0>, <obspy.core.trace.Trace object at 0x7f1ec37e85b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220214_090000.WAV
# No infrasound files found for these times
# [44, UTCDateTime(2022, 2, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3984430>, <obspy.core.trace.Trace object at 0x7f1ec3984640>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220215_090000.WAV
# No infrasound files found for these times
# [45, UTCDateTime(2022, 2, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38c54c0>, <obspy.core.trace.Trace object at 0x7f1ec38c56d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220216_090000.WAV
# No infrasound files found for these times
# [46, UTCDateTime(2022, 2, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec381b550>, <obspy.core.trace.Trace object at 0x7f1ec381b760>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220217_090000.WAV
# No infrasound files found for these times
# [47, UTCDateTime(2022, 2, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37cc640>, <obspy.core.trace.Trace object at 0x7f1ec37cc820>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220218_090000.WAV
# No infrasound files found for these times
# [48, UTCDateTime(2022, 2, 18, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3992580>, <obspy.core.trace.Trace object at 0x7f1ec3992700>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220219_090000.WAV
# No infrasound files found for these times
# [49, UTCDateTime(2022, 2, 19, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38db6d0>, <obspy.core.trace.Trace object at 0x7f1ec38db8e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220220_090000.WAV
# No infrasound files found for these times
# [50, UTCDateTime(2022, 2, 20, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3836760>, <obspy.core.trace.Trace object at 0x7f1ec3836970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220221_090000.WAV
# No infrasound files found for these times
# [51, UTCDateTime(2022, 2, 21, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37db880>, <obspy.core.trace.Trace object at 0x7f1ec37dba90>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220222_090000.WAV
# No infrasound files found for these times
# [52, UTCDateTime(2022, 2, 22, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec395c880>, <obspy.core.trace.Trace object at 0x7f1ec395ca90>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220223_090000.WAV
# No infrasound files found for these times
# [53, UTCDateTime(2022, 2, 23, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38db910>, <obspy.core.trace.Trace object at 0x7f1ec38dbb20>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220224_090000.WAV
# No infrasound files found for these times
# [54, UTCDateTime(2022, 2, 24, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38419a0>, <obspy.core.trace.Trace object at 0x7f1ec3841bb0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220225_090000.WAV
# No infrasound files found for these times
# [55, UTCDateTime(2022, 2, 25, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37dbb50>, <obspy.core.trace.Trace object at 0x7f1ec37dbc70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220226_090000.WAV
# No infrasound files found for these times
# [56, UTCDateTime(2022, 2, 26, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3979af0>, <obspy.core.trace.Trace object at 0x7f1ec3979d00>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220227_090000.WAV
# No infrasound files found for these times
# [57, UTCDateTime(2022, 2, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3901bb0>, <obspy.core.trace.Trace object at 0x7f1ec3843160>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220228_090000.WAV
# No infrasound files found for these times
# [58, UTCDateTime(2022, 2, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3826be0>, <obspy.core.trace.Trace object at 0x7f1ec3826df0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220301_090000.WAV
# No infrasound files found for these times
# [59, UTCDateTime(2022, 3, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec390ecd0>, <obspy.core.trace.Trace object at 0x7f1ec390eeb0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220302_090000.WAV
# No infrasound files found for these times
# [60, UTCDateTime(2022, 3, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37f4d60>, <obspy.core.trace.Trace object at 0x7f1ec37f4f40>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220303_090000.WAV
# No infrasound files found for these times
# [61, UTCDateTime(2022, 3, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec383fdf0>, <obspy.core.trace.Trace object at 0x7f1ec383ffd0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220304_090000.WAV
# No infrasound files found for these times
# [62, UTCDateTime(2022, 3, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec397df40>, <obspy.core.trace.Trace object at 0x7f1ec3951190>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220305_090000.WAV
# No infrasound files found for these times
# [63, UTCDateTime(2022, 3, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3928ee0>, <obspy.core.trace.Trace object at 0x7f1ec3926190>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220306_090000.WAV
# No infrasound files found for these times
# [64, UTCDateTime(2022, 3, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37c3fd0>, <obspy.core.trace.Trace object at 0x7f1ec37c71c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220307_090000.WAV
# No infrasound files found for these times
# [65, UTCDateTime(2022, 3, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec383e0a0>, <obspy.core.trace.Trace object at 0x7f1ec383e250>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220308_090000.WAV
# No infrasound files found for these times
# [66, UTCDateTime(2022, 3, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3957040>, <obspy.core.trace.Trace object at 0x7f1ec3957100>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220309_090000.WAV
# No infrasound files found for these times
# [67, UTCDateTime(2022, 3, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39b4190>, <obspy.core.trace.Trace object at 0x7f1ec39b43a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220310_090000.WAV
# No infrasound files found for these times
# [68, UTCDateTime(2022, 3, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3822220>, <obspy.core.trace.Trace object at 0x7f1ec3822430>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220311_090000.WAV
# No infrasound files found for these times
# [69, UTCDateTime(2022, 3, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37d72b0>, <obspy.core.trace.Trace object at 0x7f1ec37d74c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220312_090000.WAV
# No infrasound files found for these times
# [70, UTCDateTime(2022, 3, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38c6340>, <obspy.core.trace.Trace object at 0x7f1ec38c6550>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220313_090000.WAV
# No infrasound files found for these times
# [71, UTCDateTime(2022, 3, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec399b3d0>, <obspy.core.trace.Trace object at 0x7f1ec399b5e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220314_090000.WAV
# No infrasound files found for these times
# [72, UTCDateTime(2022, 3, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3832460>, <obspy.core.trace.Trace object at 0x7f1ec3832670>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220315_090000.WAV
# No infrasound files found for these times
# [73, UTCDateTime(2022, 3, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37f4550>, <obspy.core.trace.Trace object at 0x7f1ec37f4730>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220316_090000.WAV
# No infrasound files found for these times
# [74, UTCDateTime(2022, 3, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec378a580>, <obspy.core.trace.Trace object at 0x7f1ec378a790>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220317_090000.WAV
# No infrasound files found for these times
# [75, UTCDateTime(2022, 3, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3987520>, <obspy.core.trace.Trace object at 0x7f1ec3987760>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220318_090000.WAV
# No infrasound files found for these times
# [76, UTCDateTime(2022, 3, 18, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec381c790>, <obspy.core.trace.Trace object at 0x7f1ec381c970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220319_090000.WAV
# No infrasound files found for these times
# [77, UTCDateTime(2022, 3, 19, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37de790>, <obspy.core.trace.Trace object at 0x7f1ec37de970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220320_090000.WAV
# No infrasound files found for these times
# [78, UTCDateTime(2022, 3, 20, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37bc7c0>, <obspy.core.trace.Trace object at 0x7f1ec37bc9d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220321_090000.WAV
# No infrasound files found for these times
# [79, UTCDateTime(2022, 3, 21, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3903850>, <obspy.core.trace.Trace object at 0x7f1ec3903a60>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220322_090000.WAV
# No infrasound files found for these times
# [80, UTCDateTime(2022, 3, 22, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec383f8e0>, <obspy.core.trace.Trace object at 0x7f1ec383faf0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220323_090000.WAV
# No infrasound files found for these times
# [81, UTCDateTime(2022, 3, 23, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37d29d0>, <obspy.core.trace.Trace object at 0x7f1ec37d2bb0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220324_090000.WAV
# No infrasound files found for these times
# [82, UTCDateTime(2022, 3, 24, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37b6a00>, <obspy.core.trace.Trace object at 0x7f1ec37b6c10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220325_090000.WAV
# No infrasound files found for these times
# [83, UTCDateTime(2022, 3, 25, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec387ea90>, <obspy.core.trace.Trace object at 0x7f1ec387eca0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220326_090000.WAV
# No infrasound files found for these times
# [84, UTCDateTime(2022, 3, 26, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3822a30>, <obspy.core.trace.Trace object at 0x7f1ec3822c70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220327_090000.WAV
# No infrasound files found for these times
# [85, UTCDateTime(2022, 3, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3966bb0>, <obspy.core.trace.Trace object at 0x7f1ec3966dc0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220328_090000.WAV
# No infrasound files found for these times
# [86, UTCDateTime(2022, 3, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3784c40>, <obspy.core.trace.Trace object at 0x7f1ec3784e50>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220329_090000.WAV
# No infrasound files found for these times
# [87, UTCDateTime(2022, 3, 29, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec381bcd0>, <obspy.core.trace.Trace object at 0x7f1ec381bee0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220330_090000.WAV
# No infrasound files found for these times
# [88, UTCDateTime(2022, 3, 30, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3865d60>, <obspy.core.trace.Trace object at 0x7f1ec3865f70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220331_090000.WAV
# No infrasound files found for these times
# [89, UTCDateTime(2022, 3, 31, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3942df0>, <obspy.core.trace.Trace object at 0x7f1ec3942fd0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220401_090000.WAV
# No infrasound files found for these times
# [90, UTCDateTime(2022, 4, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37bbe80>, <obspy.core.trace.Trace object at 0x7f1ec378c0d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220402_090000.WAV
# No infrasound files found for these times
# [91, UTCDateTime(2022, 4, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec382af10>, <obspy.core.trace.Trace object at 0x7f1ec3808160>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220403_090000.WAV
# No infrasound files found for these times
# [92, UTCDateTime(2022, 4, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3908040>, <obspy.core.trace.Trace object at 0x7f1ec39081f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220404_090000.WAV
# No infrasound files found for these times
# [93, UTCDateTime(2022, 4, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39440d0>, <obspy.core.trace.Trace object at 0x7f1ec3944280>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220405_090000.WAV
# No infrasound files found for these times
# [94, UTCDateTime(2022, 4, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3797070>, <obspy.core.trace.Trace object at 0x7f1ec3797190>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220406_090000.WAV
# No infrasound files found for these times
# [95, UTCDateTime(2022, 4, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39aa1c0>, <obspy.core.trace.Trace object at 0x7f1ec39aa310>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220407_090000.WAV
# No infrasound files found for these times
# [96, UTCDateTime(2022, 4, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3832280>, <obspy.core.trace.Trace object at 0x7f1ec3832460>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220408_090000.WAV
# No infrasound files found for these times
# [97, UTCDateTime(2022, 4, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393a310>, <obspy.core.trace.Trace object at 0x7f1ec393a4f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220409_090000.WAV
# No infrasound files found for these times
# [98, UTCDateTime(2022, 4, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39563d0>, <obspy.core.trace.Trace object at 0x7f1ec39565e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220410_090000.WAV
# No infrasound files found for these times
# [99, UTCDateTime(2022, 4, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39843d0>, <obspy.core.trace.Trace object at 0x7f1ec39845e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220411_090000.WAV
# No infrasound files found for these times
# [100, UTCDateTime(2022, 4, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3828460>, <obspy.core.trace.Trace object at 0x7f1ec3828670>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220412_090000.WAV
# No infrasound files found for these times
# [101, UTCDateTime(2022, 4, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393c4f0>, <obspy.core.trace.Trace object at 0x7f1ec393c700>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220413_090000.WAV
# No infrasound files found for these times
# [102, UTCDateTime(2022, 4, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec394a490>, <obspy.core.trace.Trace object at 0x7f1ec394a610>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220414_090000.WAV
# No infrasound files found for these times
# [103, UTCDateTime(2022, 4, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37cd670>, <obspy.core.trace.Trace object at 0x7f1ec37cd850>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220415_090000.WAV
# No infrasound files found for these times
# [104, UTCDateTime(2022, 4, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39936a0>, <obspy.core.trace.Trace object at 0x7f1ec39938b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220416_090000.WAV
# No infrasound files found for these times
# [105, UTCDateTime(2022, 4, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3833730>, <obspy.core.trace.Trace object at 0x7f1ec3833940>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220417_090000.WAV
# No infrasound files found for these times
# [106, UTCDateTime(2022, 4, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3921850>, <obspy.core.trace.Trace object at 0x7f1ec3921a60>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220418_090000.WAV
# No infrasound files found for these times
# [107, UTCDateTime(2022, 4, 18, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37c38b0>, <obspy.core.trace.Trace object at 0x7f1ec37c3a90>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220419_090000.WAV
# No infrasound files found for these times
# [108, UTCDateTime(2022, 4, 19, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a68e0>, <obspy.core.trace.Trace object at 0x7f1ec39a6af0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220420_090000.WAV
# No infrasound files found for these times
# [109, UTCDateTime(2022, 4, 20, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3839970>, <obspy.core.trace.Trace object at 0x7f1ec3839b80>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220421_090000.WAV
# No infrasound files found for these times
# [110, UTCDateTime(2022, 4, 21, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec391fa00>, <obspy.core.trace.Trace object at 0x7f1ec391fc10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220422_090000.WAV
# No infrasound files found for these times
# [111, UTCDateTime(2022, 4, 22, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37fa9a0>, <obspy.core.trace.Trace object at 0x7f1ec37fab20>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220423_090000.WAV
# No infrasound files found for these times
# [112, UTCDateTime(2022, 4, 23, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3798c40>, <obspy.core.trace.Trace object at 0x7f1ec3798e50>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220424_090000.WAV
# No infrasound files found for these times
# [113, UTCDateTime(2022, 4, 24, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec382bc10>, <obspy.core.trace.Trace object at 0x7f1ec382bdf0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220425_090000.WAV
# No infrasound files found for these times
# [114, UTCDateTime(2022, 4, 25, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec391ac40>, <obspy.core.trace.Trace object at 0x7f1ec391ae50>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220426_090000.WAV
# No infrasound files found for these times
# [115, UTCDateTime(2022, 4, 26, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37fad30>, <obspy.core.trace.Trace object at 0x7f1ec37faf10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220427_090000.WAV
# No infrasound files found for these times
# [116, UTCDateTime(2022, 4, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec378edc0>, <obspy.core.trace.Trace object at 0x7f1ec378efa0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220428_090000.WAV
# No infrasound files found for these times
# [117, UTCDateTime(2022, 4, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3834e50>, <obspy.core.trace.Trace object at 0x7f1ec3834fd0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220429_090000.WAV
# No infrasound files found for these times
# [118, UTCDateTime(2022, 4, 29, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3927ee0>, <obspy.core.trace.Trace object at 0x7f1ec39230d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220430_090000.WAV
# No infrasound files found for these times
# [119, UTCDateTime(2022, 4, 30, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37faf70>, <obspy.core.trace.Trace object at 0x7f1ec37ca160>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220501_090000.WAV
# No infrasound files found for these times
# [120, UTCDateTime(2022, 5, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec378bf10>, <obspy.core.trace.Trace object at 0x7f1ec37b8070>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220502_090000.WAV
# No infrasound files found for these times
# [121, UTCDateTime(2022, 5, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39790a0>, <obspy.core.trace.Trace object at 0x7f1ec3979250>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220503_090000.WAV
# No infrasound files found for these times
# [122, UTCDateTime(2022, 5, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39020d0>, <obspy.core.trace.Trace object at 0x7f1ec39022e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220504_090000.WAV
# No infrasound files found for these times
# [123, UTCDateTime(2022, 5, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37e71c0>, <obspy.core.trace.Trace object at 0x7f1ec37e73a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220505_090000.WAV
# No infrasound files found for these times
# [124, UTCDateTime(2022, 5, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39931f0>, <obspy.core.trace.Trace object at 0x7f1ec3993400>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220506_090000.WAV
# No infrasound files found for these times
# [125, UTCDateTime(2022, 5, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec397a280>, <obspy.core.trace.Trace object at 0x7f1ec397a490>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220507_090000.WAV
# No infrasound files found for these times
# [126, UTCDateTime(2022, 5, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3916310>, <obspy.core.trace.Trace object at 0x7f1ec3916520>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220508_090000.WAV
# No infrasound files found for these times
# [127, UTCDateTime(2022, 5, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37cf3a0>, <obspy.core.trace.Trace object at 0x7f1ec37cf5b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220509_090000.WAV
# No infrasound files found for these times
# [128, UTCDateTime(2022, 5, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3819430>, <obspy.core.trace.Trace object at 0x7f1ec3819640>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220510_090000.WAV
# No infrasound files found for these times
# [129, UTCDateTime(2022, 5, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3963400>, <obspy.core.trace.Trace object at 0x7f1ec3963580>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220511_090000.WAV
# No infrasound files found for these times
# [130, UTCDateTime(2022, 5, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39114f0>, <obspy.core.trace.Trace object at 0x7f1ec3911700>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220512_090000.WAV
# No infrasound files found for these times
# [131, UTCDateTime(2022, 5, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37cf580>, <obspy.core.trace.Trace object at 0x7f1ec37cf790>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220513_090000.WAV
# No infrasound files found for these times
# [132, UTCDateTime(2022, 5, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3840670>, <obspy.core.trace.Trace object at 0x7f1ec3840850>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220514_090000.WAV
# No infrasound files found for these times
# [133, UTCDateTime(2022, 5, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec398e6a0>, <obspy.core.trace.Trace object at 0x7f1ec398e8b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220515_090000.WAV
# No infrasound files found for these times
# [134, UTCDateTime(2022, 5, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393f790>, <obspy.core.trace.Trace object at 0x7f1ec393f970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220516_090000.WAV
# No infrasound files found for these times
# [135, UTCDateTime(2022, 5, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37dd820>, <obspy.core.trace.Trace object at 0x7f1ec37dda00>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220517_090000.WAV
# No infrasound files found for these times
# [136, UTCDateTime(2022, 5, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38147f0>, <obspy.core.trace.Trace object at 0x7f1ec3814af0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220518_090000.WAV
# No infrasound files found for these times
# ...
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220627_090000.WAV
# No infrasound files found for these times
# [177, UTCDateTime(2022, 6, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3973130>, <obspy.core.trace.Trace object at 0x7f1ec39732e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220628_090000.WAV
# No infrasound files found for these times
# [178, UTCDateTime(2022, 6, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39bc130>, <obspy.core.trace.Trace object at 0x7f1ec39bc340>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220629_090000.WAV
# No infrasound files found for these times
# [179, UTCDateTime(2022, 6, 29, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec392f1c0>, <obspy.core.trace.Trace object at 0x7f1ec392f3d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220630_090000.WAV
# No infrasound files found for these times
# [180, UTCDateTime(2022, 6, 30, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec397d250>, <obspy.core.trace.Trace object at 0x7f1ec397d460>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220701_090000.WAV
# No infrasound files found for these times
# [181, UTCDateTime(2022, 7, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a62e0>, <obspy.core.trace.Trace object at 0x7f1ec39a64f0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220702_090000.WAV
# No infrasound files found for these times
# [182, UTCDateTime(2022, 7, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3919370>, <obspy.core.trace.Trace object at 0x7f1ec3919580>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220703_090000.WAV
# No infrasound files found for these times
# [183, UTCDateTime(2022, 7, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3965400>, <obspy.core.trace.Trace object at 0x7f1ec37d1040>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220704_090000.WAV
# No infrasound files found for these times
# [184, UTCDateTime(2022, 7, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec399e460>, <obspy.core.trace.Trace object at 0x7f1ec399e640>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220705_090000.WAV
# No infrasound files found for these times
# [185, UTCDateTime(2022, 7, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3913520>, <obspy.core.trace.Trace object at 0x7f1ec3913730>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220706_090000.WAV
# No infrasound files found for these times
# [186, UTCDateTime(2022, 7, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3998520>, <obspy.core.trace.Trace object at 0x7f1ec3998730>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220707_090000.WAV
# No infrasound files found for these times
# [187, UTCDateTime(2022, 7, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec385c5b0>, <obspy.core.trace.Trace object at 0x7f1ec385c7c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220708_090000.WAV
# No infrasound files found for these times
# [188, UTCDateTime(2022, 7, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39bb6a0>, <obspy.core.trace.Trace object at 0x7f1ec39bb880>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220709_090000.WAV
# No infrasound files found for these times
# [189, UTCDateTime(2022, 7, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3919730>, <obspy.core.trace.Trace object at 0x7f1ec3919910>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220710_090000.WAV
# No infrasound files found for these times
# [190, UTCDateTime(2022, 7, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a9790>, <obspy.core.trace.Trace object at 0x7f1ec39a99a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220711_090000.WAV
# No infrasound files found for these times
# [191, UTCDateTime(2022, 7, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3782820>, <obspy.core.trace.Trace object at 0x7f1ec3782a30>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220712_090000.WAV
# No infrasound files found for these times
# [192, UTCDateTime(2022, 7, 12, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3983850>, <obspy.core.trace.Trace object at 0x7f1ec39839d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220713_090000.WAV
# No infrasound files found for these times
# [193, UTCDateTime(2022, 7, 13, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37ca9d0>, <obspy.core.trace.Trace object at 0x7f1ec37cabe0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220714_090000.WAV
# No infrasound files found for these times
# [194, UTCDateTime(2022, 7, 14, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39bfa60>, <obspy.core.trace.Trace object at 0x7f1ec39bfc70>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220715_090000.WAV
# No infrasound files found for these times
# [195, UTCDateTime(2022, 7, 15, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37a0af0>, <obspy.core.trace.Trace object at 0x7f1ec37a0d00>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220716_090000.WAV
# No infrasound files found for these times
# [196, UTCDateTime(2022, 7, 16, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38c3b80>, <obspy.core.trace.Trace object at 0x7f1ec38c3d90>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220717_090000.WAV
# No infrasound files found for these times
# [197, UTCDateTime(2022, 7, 17, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec398dc10>, <obspy.core.trace.Trace object at 0x7f1ec398de20>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220718_090000.WAV
# No infrasound files found for these times
# [198, UTCDateTime(2022, 7, 18, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37f6ca0>, <obspy.core.trace.Trace object at 0x7f1ec37f6eb0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220719_090000.WAV
# No infrasound files found for these times
# [199, UTCDateTime(2022, 7, 19, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37b7d30>, <obspy.core.trace.Trace object at 0x7f1ec37b7f40>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220720_090000.WAV
# No infrasound files found for these times
# [200, UTCDateTime(2022, 7, 20, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec399edc0>, <obspy.core.trace.Trace object at 0x7f1ec399efd0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220721_090000.WAV
# No infrasound files found for these times
# [201, UTCDateTime(2022, 7, 21, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38cde50>, <obspy.core.trace.Trace object at 0x7f1ec38cc0a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220722_090000.WAV
# No infrasound files found for these times
# [202, UTCDateTime(2022, 7, 22, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3890d60>, <obspy.core.trace.Trace object at 0x7f1ec38b4b80>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220723_090000.WAV
# No infrasound files found for these times
# [203, UTCDateTime(2022, 7, 23, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39a9f40>, <obspy.core.trace.Trace object at 0x7f1ec398b190>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220724_090000.WAV
# No infrasound files found for these times
# [204, UTCDateTime(2022, 7, 24, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3928040>, <obspy.core.trace.Trace object at 0x7f1ec39282e0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220725_090000.WAV
# No infrasound files found for these times
# [205, UTCDateTime(2022, 7, 25, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3966160>, <obspy.core.trace.Trace object at 0x7f1ec3966310>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220726_090000.WAV
# No infrasound files found for these times
# [206, UTCDateTime(2022, 7, 26, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3996670>, <obspy.core.trace.Trace object at 0x7f1ec39963a0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220727_090000.WAV
# No infrasound files found for these times
# [207, UTCDateTime(2022, 7, 27, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37952b0>, <obspy.core.trace.Trace object at 0x7f1ec37954c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220728_090000.WAV
# No infrasound files found for these times
# [208, UTCDateTime(2022, 7, 28, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39c02b0>, <obspy.core.trace.Trace object at 0x7f1ec39c05b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220729_090000.WAV
# No infrasound files found for these times
# [209, UTCDateTime(2022, 7, 29, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3981340>, <obspy.core.trace.Trace object at 0x7f1ec3981550>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220730_090000.WAV
# No infrasound files found for these times
# [210, UTCDateTime(2022, 7, 30, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39992e0>, <obspy.core.trace.Trace object at 0x7f1ec3999460>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220731_090000.WAV
# No infrasound files found for these times
# [211, UTCDateTime(2022, 7, 31, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37bb460>, <obspy.core.trace.Trace object at 0x7f1ec37bb670>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220801_090000.WAV
# No infrasound files found for these times
# [212, UTCDateTime(2022, 8, 1, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39534f0>, <obspy.core.trace.Trace object at 0x7f1ec3953700>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220802_090000.WAV
# No infrasound files found for these times
# [213, UTCDateTime(2022, 8, 2, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393d5e0>, <obspy.core.trace.Trace object at 0x7f1ec393d7c0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220803_090000.WAV
# No infrasound files found for these times
# [214, UTCDateTime(2022, 8, 3, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3999670>, <obspy.core.trace.Trace object at 0x7f1ec3999910>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220804_090000.WAV
# No infrasound files found for these times
# [215, UTCDateTime(2022, 8, 4, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37ba6a0>, <obspy.core.trace.Trace object at 0x7f1ec37ba8b0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220805_090000.WAV
# No infrasound files found for these times
# [216, UTCDateTime(2022, 8, 5, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec3953790>, <obspy.core.trace.Trace object at 0x7f1ec3953970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220806_090000.WAV
# No infrasound files found for these times
# [217, UTCDateTime(2022, 8, 6, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39257c0>, <obspy.core.trace.Trace object at 0x7f1ec39259d0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220807_090000.WAV
# No infrasound files found for these times
# [218, UTCDateTime(2022, 8, 7, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec38dc8e0>, <obspy.core.trace.Trace object at 0x7f1ec38dcaf0>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220808_090000.WAV
# No infrasound files found for these times
# [219, UTCDateTime(2022, 8, 8, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37af7f0>, <obspy.core.trace.Trace object at 0x7f1ec37af970>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220809_090000.WAV
# No infrasound files found for these times
# [220, UTCDateTime(2022, 8, 9, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec39be970>, <obspy.core.trace.Trace object at 0x7f1ec39beb80>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220810_090000.WAV
# No infrasound files found for these times
# [221, UTCDateTime(2022, 8, 10, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec393aa00>, <obspy.core.trace.Trace object at 0x7f1ec393ac10>]
# No infrasound files found in path /home/scott/bender/gradschool/data/CON1E_all/infra
# Reading file /home/scott/bender/gradschool/data/CON1E_all/aud/20220811_090000.WAV
# No infrasound files found for these times
# [222, UTCDateTime(2022, 8, 11, 0, 0), <obspy.core.trace.Trace object at 0x7f1ec37dbb20>, <obspy.core.trace.Trace object at 0x7f1ec37dbd30>]

# %%
## reformat result lists from the loop into numpy arrays that are easy to plot
# w = (freqs_infrasound_all < 40) & (freqs_infrasound_all > 5)
# freqs_infrasound = freqs_infrasound_all[w]    
# meanspec_infrasound = reformat(meanspec_list_infrasound)[:,w]
# medspec_infrasound = reformat(medspec_list_infrasound)[:,w]
# power_infrasound = medspec_infrasound.sum(1) * np.diff(freqs_infrasound)[0]

w = (freqs_audible_all < 20000) & (freqs_audible_all > 40)
freqs_audible = freqs_audible_all[w]    
meanspec_audible = reformat(meanspec_list_audible)[:,w]
medspec_audible = reformat(medspec_list_audible)[:,w]
power_audible = medspec_audible.sum(1) * np.diff(freqs_audible)[0]

xlim = [np.min(times_infrasound), np.max(times_infrasound)]
if site == 'LG':
    t, q = riversound.read_DCEW(filename = '/home/scott/bender/gradschool/data/LG_StreamHrlySummary_20' + year + '_new.csv')
elif site == 'CON1E':
    t, q = riversound.read_DCEW(filename = '/home/scott/bender/gradschool/data/C1E_StreamHrlySummary_20' + year + '_new.csv')
elif site == 'CON1W':
     t, q = riversound.read_DCEW(filename = '/home/scott/bender/gradschool/data/C1W_StreamHrlySummary_20' + year + '_new.csv')
else:
    t, q = riversound.read_discharge('glenwood', xlim[0] - datetime.timedelta(days=1), xlim[1] + datetime.timedelta(days=1)) 

 
## plot the discharge, power, and spectrogram
plt.figure(figsize = (12,6)) 
plt.subplot(3,1,1) # discharge
# plt.plot(t,q)
Q_time = interp_times(times_infrasound, t, q)
plt.plot(times_infrasound, Q_time, 'r.-')
#plt.ylim([np.min(Q_time)- 0.5*np.min(Q_time), np.max(Q_time)+ 0.5*np.max(Q_time)])
plt.xticks([], fontsize = 18)
q_ticks = [0,-1]
plt.yticks(fontsize = 16)
plt.xlim(xlim[0], xlim[1])
plt.ylabel('Discharge (m$^3$/s)', fontsize = 16)
plt.title(station_name + ' Spring Acoustic Hydrograph', fontsize = 26)

# plot labels for FB1 drone points
# indices_fb1 = [1, 7, 10, 15]
# #indices_fb1 = [4, 11, int(n_days/2)-2]
# discharge_fb1 = [Q_time[i] for i in indices_fb1]
# marker_indices = [times_audible[i] for i in indices_fb1]
# plt.scatter(marker_indices, discharge_fb1,  marker= '*', s= 200, color = 'blue')
# addition = [1.3* k for k in discharge_fb1]
# plt.plot(marker_indices[0], addition[0]+10, marker="$A$", markersize=14, color = 'black', markeredgecolor="black")
# plt.plot(marker_indices[1], addition[1]+10, marker="$B$", markersize=14, color = 'black', markeredgecolor="black")
# plt.plot(marker_indices[2], addition[2]+10, marker="$C$", markersize=14, color = 'black', markeredgecolor="black")
# plt.plot(marker_indices[3], addition[3], marker="$D$", markersize=14, color = 'black', markeredgecolor="black")

plt.subplot(3,1,2) # power
#plt.plot(times_infrasound, power_infrasound, '.-', label = '5-40 Hz Band')
#plt.plot(times_infrasound, infra_power_band_limit[0], 'b--.', label = str(infra_freqs_low[0]) + '-' + str(infra_freqs_high[0]) + ' Hz Band' )
#plt.plot(times_infrasound, infra_power_band_limit[1], 'r--.', label = str(infra_freqs_low[1]) + '-' + str(infra_freqs_high[1]) + ' Hz Band' )
#plt.plot(times_infrasound, infra_power_band_limit[2], 'k--.', label = str(infra_freqs_low[2]) + '-' + str(infra_freqs_high[2]) + ' Hz Band' )
#plt.ylim(0,0.004)
plt.semilogy(times_audible, power_audible, 'r.-', label = '40-20000 Hz Band')
#plt.semilogy(times_audible, aud_power_band_limit[0], '.-', linewidth = 2, label = str(aud_freqs_low[0]) + '-' + str(aud_freqs_high[0]) + ' Hz Band')
#for y in infra_power_band_limit:
#   plt.semilogy(times_infrasound, y, linewidth = 2, label = str(infra_freqs_low[0]) + '-' + str(infra_freqs_high[0]) + ' Hz Band')

# for y in aud_power_band_limit:

    #power_audible_band = y
    #band_fb1 = [y[i] for i in indices_fb1]
    #plt.scatter(marker_indices, band_fb1,  marker= '*', s= 100, color = 'blue')
#plt.legend(loc= (0.25, 0.65), prop={'size': 10})
plt.legend(loc= 'best', fontsize = 8)
plt.xlim(xlim[0], xlim[1])
plt.ylabel('Power (Pa$^2$)', fontsize = 16)
plt.yticks(fontsize = 16)
plt.xticks([])
plt.xticks(fontsize = 18)

# indices_fb1 = np.array([int(n_days/2)+4, int(n_days/4)+5, int(n_days*0.75), -3])
# power_fb1 = [power_audible[i] for i in indices_fb1]
# g = [times_audible[i] for i in indices_fb1]
# plt.scatter(g, power_fb1,  marker= '*', s= 100, color = 'blue')

plt.subplot(3,1,3) # spectrogram
#plt.plot(times_infrasound, riversound.find_mean_freq(meanspec_infrasound, freqs_infrasound, 13))
#plt.plot(times_audible, riversound.find_mean_freq(meanspec_audible, freqs_audible, 13))
#riversound.image(np.log10(medspec_infrasound), times_infrasound, freqs_infrasound, crosshairs = False, log_y = True) # aud and infra log_y must match
riversound.image(np.log10(medspec_audible), times_audible, freqs_audible, crosshairs = False, log_y = True)
plt.xlim(xlim[0], xlim[1])
plt.yticks(np.arange(5), 10**np.arange(5), fontsize = 16)
pdtimes_infrasound =  pd.to_datetime(times_infrasound)
indices1 = [0,26,57,87,118,149,170] # for full 2021 Ridenbaugh: [0,26,57,87,118,149,170]

indices_general = [0, int(n_days/2), int(n_days/4), int(n_days*0.75), -1]
#indices_fb1 = [4, 11, int(n_days/2)-2, int(n_days*0.75), -3] # for spring figure
g = pdtimes_infrasound.strftime('%b %d')
g = [g[inds] for inds in indices_general]
ticks = [pdtimes_infrasound[inds] for inds in indices_general]
plt.xticks(ticks = ticks, labels = g, fontsize = 24)
plt.yticks(fontsize = 16)
plt.ylabel('Frequency (Hz)', fontsize = 16)
plt.tight_layout()
plt.ylim(1.52,4)
#plt.hlines(y = 3, xmin = np.min(times_audible), xmax = np.max(times_audible))
#plt.savefig('June-SeptEckert2021_hydrograph')
# Out:
# (1.52, 4.0)

# %%
# plot discharge vs sound power
plt.figure(figsize = (12,6))
plt.title(station_name + ' Fall Power Rating Curve')

#plt.semilogy(Q_time, power_infrasound, 'b.-', markersize = 12, label = '5-40 Hz Band')
#plt.semilogy(Q_time, infra_power_band_limit[0], 'b--.', label = str(infra_freqs_low[0]) + '-' + str(infra_freqs_high[0]) + ' Hz Band' )
#plt.semilogy(Q_time, infra_power_band_limit[1], 'r--.', label = str(infra_freqs_low[1]) + '-' + str(infra_freqs_high[1]) + ' Hz Band' )
#plt.semilogy(times_infrasound, infra_power_band_limit[2], 'k--.', label = str(infra_freqs_low[2]) + '-' + str(infra_freqs_high[2]) + ' Hz Band' )

plt.semilogy(Q_time, power_audible, 'r.-', markersize = 12, label = '40-20000 Hz Band')
#plt.semilogy(Q_time, aud_power_band_limit[0], 'k.-.', label = str(aud_freqs_low[0]) + '-' + str(aud_freqs_high[0]) + ' Hz Band' )
# for y in infra_power_band_limit:
#     plt.semilogy(Q_time, y, 'r.-', markersize = 12, label = str(infra_freqs_low) + '-' + str(infra_freqs_high) + ' Hz Band')

plt.xlabel('Discharge (m$^3$/s)', fontsize = 22)
plt.ylabel('Power (Pa$^2$)', fontsize = 22)
plt.legend(fontsize = 10)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
# label points by date
indices = [-1,0,9,25,42,44,56,-5]
indices_general = [0, int(n_days/2), int(n_days/4), int(n_days*0.75), -1]
#power2_infrasound = [power_infrasound[z] for z in indices_general]
power2_audible = [power_audible[z] for z in indices_general]
times2_infrasound = pdtimes_infrasound
times2_infrasound = [times2_infrasound[z] for z in indices_general]
X = interp_times(times2_infrasound, t, q)

#Y = power2_infrasound
#Y = power2_audible

# for i, label in enumerate(times2_infrasound):
#     plt.text( X[i],Y[i],label.strftime('%b %d'), fontsize = 18, weight = "bold")
# power2_audible = [power_audible[z] for z in indices]
# times2_audible = pd.to_datetime(times_audible, format = '%d', dayfirst = True)
# times2_audible = [times2_audible[z] for z in indices]
# X2 = interp_times(times2_audible, t, q)
# Y2 = power2_audible
# for i, label in enumerate(times2_audible):
#     plt.text( X2[i],Y2[i],label.strftime('%m-%d')
# plot 1:1 relationship

# %%
# plt.figure(figsize = (12,6)) 
# num_colors = len(plt.rcParams['axes.prop_cycle'].by_key()['color'])
# for ii in range(n_days):
#     col = plt.rcParams['axes.prop_cycle'].by_key()['color'][ii%num_colors]
#     plt.loglog(X, Y[ii,:], color = col)
#     #plt.loglog(X2, Y2[ii,:], color = col, label = plot_times[ii].strftime('%m-%d'))
#     plt.legend() # uses labels from plt.loglog
#     #plt.xlabel('Frequency (Hz)')
#     #plt.ylabel('Power Spectral Density (counts$^2$/Hz)')
                 
## plot discharge vs infrasound and audible peak frequencies
fig, ax1 = plt.subplots(figsize = (12,6))
ax1.set_title(station_name + ' Mean Frequency Rating Curve')
ax1.set_xlabel('Discharge (m$^3$/s)', fontsize = 22)
ax1.set_ylabel('Mean Frequency (Hz)', fontsize = 22)
#ax1.semilogy(interp_times(times_infrasound, t, q), riversound.find_mean_freq(meanspec_infrasound, freqs_infrasound, 13), 'b.-', markersize = 14)
ax2 = ax1.twinx()
ax2.semilogy(interp_times(times_audible, t, q), riversound.find_mean_freq(meanspec_audible, freqs_audible, 10), 'r.-', markersize = 14)
ax2.set_xlabel('Discharge (m$^3$/s)', fontsize = 22)
ax2.set_ylabel('Mean Frequency (Hz)', fontsize = 22)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
ax1.legend(['Infrasound'], fontsize = 18, loc= (0.25, 0.9))
ax2.legend(['Audible'], fontsize = 18, loc= (0.25, 0.8))

#mean_freq = riversound.find_mean_freq(meanspec_infrasound, freqs_infrasound, 13)
mean_freq2 = riversound.find_mean_freq(meanspec_audible, freqs_audible, 13)

plt.legend(['Infrasound'], ['Audible'], fontsize = 16)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
# indices = [-1,0,9,25,56] # turn on to evaluate separate indices
#meanfreq_infrasound = [mean_freq[z] for z in indices_general]
meanfreq_audible = [mean_freq2[z] for z in indices_general]
times2_infrasound = pdtimes_infrasound
times2_infrasound = [times2_infrasound[z] for z in indices_general]

X = interp_times(times2_infrasound, t, q)
#YY = meanfreq_infrasound
Y = meanfreq_audible 
for i, label in enumerate(times2_infrasound):
    plt.text( X[i],Y[i],label.strftime('%b %d'), fontsize = 18, weight = 'bold')
# for i, label in enumerate(times2_infrasound):
#     plt.text( X[i],YY[i],label.strftime('%b %d'), fontsize = 18, weight = 'bold')
plt.legend(['Infrasound'], ['Audible'], fontsize = 16)  

# meanfreq_audible = [mean_freq[z] for z in indices]
# times2_audible = pdtimes_infrasound
# times2_audible = [times2_audible[z] for z in indices]
# X = interp_times(times2_audible, t, q)
# Y = meanfreq_audible
# for i, label in enumerate(times2_audible):
#     plt.text( X[i],Y[i],label.strftime('%b %d'), fontsize = 18, weight = 'bold')

      ## plot the daily spectra
# plt.figure()
# num_colors = len(plt.rcParams['axes.prop_cycle'].by_key()['color'])
# for i in range(n_days):
#     col = plt.rcParams['axes.prop_cycle'].by_key()['color'][i%num_colors]
#     plt.loglog(freqs_infrasound, meanspec_infrasound[i,:], color = col)
#     #plt.loglog(freqs_audible, meanspec_audible[i,:], color = col, label = plot_times[i].strftime('%Y-%m-%d'))
#     #plt.legend() # uses labels from plt.loglog
#     plt.xlabel('Frequency (Hz)')
#     plt.ylabel('Power Spectral Density (counts$^2$/Hz)')
# Out:
# /tmp/ipykernel_141367/1411313926.py:29: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend(['Infrasound'], ['Audible'], fontsize = 16)
# /tmp/ipykernel_141367/1411313926.py:45: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend(['Infrasound'], ['Audible'], fontsize = 16)

# %%
import pickle
import os
print(os.getcwd()) # pickles are saved to cwd

Dictionary = {}
#Dictionary['power_infrasound_' + site + year + season] = power_infrasound
Dictionary['power_audible_' + site + year + season] = power_audible
#Dictionary['power_infrasound_nonzero_' + site + year + season] = power_infrasound_nonzero
#Dictionary['power_audible_nonzero_' + site + year + season] = power_audible_nonzero
#Dictionary['meanfreq_infra_' + site + year + season] = mean_freq
Dictionary['meanfreq_aud_' + site + year + season] = mean_freq2
#Dictionary['times_infra_' + site + year + season] = times_infrasound
Dictionary['times_aud_' + site + year + season] = times_audible

#Q_infra = interp_times(times_infrasound, t, q)
Q_aud = interp_times(times_audible, t, q)

#Dictionary['Q_infra_' + site + year + season] = Q_infra
Dictionary['Q_aud_' + site + year + season] = Q_aud
#Dictionary['Q_infra_nonzero_' + site + year + season] = Q_time_infra_index

#Dictionary['Q_aud_nonzero_' + site + year + season] = Q_time_aud
#Dictionary['aud_meanfreq_filtered_' + site + year + season] = aud_meanfreq_filtered

# pickle that shit
with open(site + year + season + '.pickle', 'wb') as handle:
    pickle.dump(Dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(site + year + season + '.pickle', 'rb') as handle:
    b = pickle.load(handle)
# Out:
# /home/scott/bender/gradschool/code/riversound/examples/Spring_2022_code/Boise_dams
